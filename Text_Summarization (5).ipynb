# %% [markdown]
# ## <font color="#F0000"> Text summarization avec nltk

# %% [markdown]
# ### <font color="#48dbfb"> Import les packages

# %%
# Importer packages
import base64
import streamlit as st
from PIL import ImageOps, Image
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, BatchNormalization, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from bs4 import BeautifulSoup as bs
from requests import get
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### <font color="#48dbfb">Scraper des articles sur Wikipedia

# %%
# Importer des données sur la cuisine iraniéne
resp = get('https://en.wikipedia.org/wiki/Iranian_cuisine')
# resp = get('https://fr.wikipedia.org/wiki/Cuisine_iranienne')

article_soup = bs(resp.text)

paragraphs = article_soup.find_all('p')

article_text = ""

for p in paragraphs:
    article_text += p.text

# %%
# Afficher article_text
article_text
# Out:
# '\nIranian cuisine (Persian: آشپزی ایرانی, romanized:\xa0Āshpazī Irānī) are the culinary traditions of Iran. Due to the historically common usage of the term "Persia" to refer to Iran in the Western world,[2][3][4] it is alternatively known as Persian cuisine, despite Persians being only one of a multitude of Iranian ethnic groups who have contributed to Iran\'s culinary traditions.[a]\nThe cuisine of Iran has made extensive contact throughout its history with the cuisines of its neighbouring regions, including Caucasian cuisine, Central Asian cuisine, Greek cuisine, Levantine cuisine, Mesopotamian cuisine, Russian cuisine and Turkish cuisine.[6][7][8][9] Aspects of Iranian cuisine have also been significantly adopted by Indian cuisine and Pakistani cuisine through various historical Persianate sultanates that flourished during Muslim rule on the Indian subcontinent, with the most notable and impactful of these polities being the Mughal Empire.[10][11][12]\nTypical Iranian main dishes are combinations of rice with meat, vegetables and nuts. Herbs are frequently used, along with fruits such as plums, pomegranates, quince, prunes, apricots and raisins. Characteristic Iranian spices and flavourings such as saffron, cardamom, and dried lime and other sources of sour flavoring, cinnamon, turmeric and parsley are mixed and used in various dishes.\nOutside of Iran, a strong presence of Iranian cuisine can be found in cities with significant Iranian diaspora populations, namely the San Francisco Bay Area, Vancouver, Toronto,[13][14][15][16] Houston and especially Los Angeles and its environs.[13][14][17]\nAmong the writings available from the Middle Persian scripts, the treatise of Khosrow and Ridag, points about stews and foods and the way of using them and how they are obtained in the Sassanid period are found as valid references in compiling the history of cooking in Iran. The names of many of the Iranian dishes and culinary terms that have been translated can be seen in Arabic language books. Naturally the customs and habits of the Arabs influenced the Iranians, specifically in Abbasid period.\nAncient Persian philosophers and physicians have influenced the preparation of Iranian foods to follow the rules of the strengthening and weakening characteristics of foods based on the Iranian traditional medicine.[18]\nAlthough the Arabic cookbooks written under the rule of the Abbasid Caliphate—one of the Arab caliphates which ruled Iran after the Muslim invasion—include some recipes with Iranian names, the earliest surviving classical cookbooks in Persian are two volumes from the Safavid period. The older one is entitled "Manual on cooking and its craft" (Kār-nāmeh dar bāb e tabbāxī va sanat e ān) written in 927/1521 for an aristocratic patron at the end of the reign of Ismail I. The book originally contained 26 chapters, listed by the author in his introduction, but chapters 23 through 26 are missing from the surviving manuscript. The recipes include measurements for ingredients—often detailed directions for the preparation of dishes, including the types of utensils and pots to be used—and instructions for decorating and serving them. In general, the ingredients and their combinations in various recipes do not differ significantly from those in use today. The large quantities specified, as well as the generous use of such luxury ingredients as saffron, suggest that these dishes were prepared for large aristocratic households, even though in his introduction, the author claimed to have written it "for the benefit of the nobility, as well as the public."\nThe second surviving Safavid cookbook, entitled "The substance of life, a treatise on the art of cooking" (Māddat al-ḥayāt, resāla dar ʿelm e ṭabbāxī), was written about 76 years later by a chef for Abbas I. The introduction of that book includes elaborate praise of God, the prophets, the imams, and the shah, as well as a definition of a master chef. It is followed by six chapters on th ...

# %% [markdown]
# ### <font color="#48dbfb"> Nettoyer les données

# %%
# Supprimer [\w]*
article_text = re.sub(r'[[\w]*]', ' ', article_text)
# Supprimer les chaines de \xa0, \u200c
article_text = re.sub(r'\xa0|\u200c', ' ', article_text)
# Remplacer les espaces multiples par l'espace simple
article_text = re.sub(r'/s+', ' ', article_text)
# Remplacer l'espace en debut et fin de corpus
article_text = re.sub(r'^\s|\s$', '', article_text)

article_text = re.sub(r'\n', '', article_text)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19352\2049198037.py:2: FutureWarning: Possible nested set at position 1
#   article_text = re.sub(r'[[\w]*]', ' ', article_text)

# %%
# Afficher article_text
article_text
# Out:
# 'Iranian cuisine (Persian: آشپزی ایرانی, romanized: Āshpazī Irānī) are the culinary traditions of Iran. Due to the historically common usage of the term "Persia" to refer to Iran in the Western world,    it is alternatively known as Persian cuisine, despite Persians being only one of a multitude of Iranian ethnic groups who have contributed to Iran\'s culinary traditions. The cuisine of Iran has made extensive contact throughout its history with the cuisines of its neighbouring regions, including Caucasian cuisine, Central Asian cuisine, Greek cuisine, Levantine cuisine, Mesopotamian cuisine, Russian cuisine and Turkish cuisine.     Aspects of Iranian cuisine have also been significantly adopted by Indian cuisine and Pakistani cuisine through various historical Persianate sultanates that flourished during Muslim rule on the Indian subcontinent, with the most notable and impactful of these polities being the Mughal Empire.   Typical Iranian main dishes are combinations of rice with meat, vegetables and nuts. Herbs are frequently used, along with fruits such as plums, pomegranates, quince, prunes, apricots and raisins. Characteristic Iranian spices and flavourings such as saffron, cardamom, and dried lime and other sources of sour flavoring, cinnamon, turmeric and parsley are mixed and used in various dishes.Outside of Iran, a strong presence of Iranian cuisine can be found in cities with significant Iranian diaspora populations, namely the San Francisco Bay Area, Vancouver, Toronto,     Houston and especially Los Angeles and its environs.   Among the writings available from the Middle Persian scripts, the treatise of Khosrow and Ridag, points about stews and foods and the way of using them and how they are obtained in the Sassanid period are found as valid references in compiling the history of cooking in Iran. The names of many of the Iranian dishes and culinary terms that have been translated can be seen in Arabic language books. Naturally the customs and habits of the Arabs influenced the Iranians, specifically in Abbasid period.Ancient Persian philosophers and physicians have influenced the preparation of Iranian foods to follow the rules of the strengthening and weakening characteristics of foods based on the Iranian traditional medicine. Although the Arabic cookbooks written under the rule of the Abbasid Caliphate—one of the Arab caliphates which ruled Iran after the Muslim invasion—include some recipes with Iranian names, the earliest surviving classical cookbooks in Persian are two volumes from the Safavid period. The older one is entitled "Manual on cooking and its craft" (Kār-nāmeh dar bāb e tabbāxī va sanat e ān) written in 927/1521 for an aristocratic patron at the end of the reign of Ismail I. The book originally contained 26 chapters, listed by the author in his introduction, but chapters 23 through 26 are missing from the surviving manuscript. The recipes include measurements for ingredients—often detailed directions for the preparation of dishes, including the types of utensils and pots to be used—and instructions for decorating and serving them. In general, the ingredients and their combinations in various recipes do not differ significantly from those in use today. The large quantities specified, as well as the generous use of such luxury ingredients as saffron, suggest that these dishes were prepared for large aristocratic households, even though in his introduction, the author claimed to have written it "for the benefit of the nobility, as well as the public."The second surviving Safavid cookbook, entitled "The substance of life, a treatise on the art of cooking" (Māddat al-ḥayāt, resāla dar ʿelm e ṭabbāxī), was written about 76 years later by a chef for Abbas I. The introduction of that book includes elaborate praise of God, the prophets, the imams, and the shah, as well as a definition of a master chef. It is followed by six chapters on the preparation of various dishes: four on rice dishes, one on qalya,  ...

# %% [markdown]
# ### <font color="#48dbfb"> Text Summarization

# %% [markdown]
# #### <font color="#fd79a8">Tokeniser en phrase

# %%
# Tokeniser en phrase
sentence_list = nltk.sent_tokenize(article_text)

# %% [markdown]
# #### <font color="#fd79a8"> Calculer les frequences des mots

# %%
# Stopwords
stopwords = nltk.corpus.stopwords.words('english')
# Dictionnaire de fréquences des mots
word_frequencies = {}
for word in nltk.word_tokenize(article_text):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
# Afficher word_frequencies
word_frequencies
# Out:
# {'Iranian': 48,
#  'cuisine': 23,
#  '(': 35,
#  'Persian': 10,
#  ':': 8,
#  'آشپزی': 1,
#  'ایرانی': 1,
#  ',': 234,
#  'romanized': 1,
#  'Āshpazī': 1,
#  'Irānī': 1,
#  ')': 35,
#  'culinary': 3,
#  'traditions': 2,
#  'Iran': 32,
#  '.': 97,
#  'Due': 1,
#  'historically': 2,
#  'common': 5,
#  'usage': 2,
#  'term': 2,
#  '``': 12,
#  'Persia': 1,
#  "''": 10,
#  'refer': 1,
#  'Western': 1,
#  'world': 4,
#  'alternatively': 1,
#  'known': 3,
#  'despite': 1,
#  'Persians': 1,
#  'one': 9,
#  'multitude': 1,
#  'ethnic': 1,
#  'groups': 2,
#  'contributed': 1,
#  "'s": 11,
#  'The': 21,
#  'made': 14,
#  'extensive': 1,
#  'contact': 1,
#  'throughout': 1,
#  'history': 2,
#  'cuisines': 1,
#  'neighbouring': 1,
#  'regions': 3,
#  'including': 5,
#  'Caucasian': 1,
#  'Central': 1,
#  'Asian': 1,
#  'Greek': 1,
#  'Levantine': 1,
#  'Mesopotamian': 1,
#  'Russian': 1,
#  'Turkish': 3,
#  'Aspects': 1,
#  'also': 23,
#  'significantly': 2,
#  'adopted': 2,
#  'Indian': 2,
#  'Pakistani': 1,
#  'various': 15,
#  'historical': 1,
#  'Persianate': 1,
#  'sultanates': 1,
#  'flourished': 1,
#  'Muslim': 2,
#  'rule': 2,
#  'subcontinent': 1,
#  'notable': 2,
#  'impactful': 1,
#  'polities': 1,
#  'Mughal': 1,
#  'Empire': 2,
#  'Typical': 1,
#  'main': 3,
#  'dishes': 29,
#  'combinations': 3,
#  'rice': 26,
#  'meat': 13,
#  'vegetables': 7,
#  'nuts': 3,
#  'Herbs': 1,
#  'frequently': 1,
#  'used': 13,
#  'along': 2,
#  'fruits': 8,
#  'plums': 2,
#  'pomegranates': 1,
#  'quince': 1,
#  'prunes': 1,
#  'apricots': 2,
#  'raisins': 2,
#  'Characteristic': 1,
#  'spices': 4,
#  'flavourings': 1,
#  'saffron': 6,
#  'cardamom': 2,
#  'dried': 4,
#  'lime': 1,
#  'sources': 1,
#  'sour': 3,
#  'flavoring': 1,
#  'cinnamon': 1,
#  'turmeric': 1,
#  'parsley': 1,
#  'mixed': 3,
#  'dishes.Outside': 1,
#  'strong': 2,
#  'presence': 2,
#  'found': 2,
#  'cities': 3,
#  'significant': 2,
#  'diaspora': 1,
#  'populations': 1,
#  'namely': 1,
#  'San': 1,
#  'Francisco': 1,
#  'Bay': 1,
#  'Area': 1,
#  'Vancouver': 1,
#  'Toronto': 1,
#  'Houston': 1,
#  'especially': 3,
#  'Los': 1,
#  'Angeles': 1,
#  'environs': 1,
#  'Among': 1,
#  'writings': 1,
#  'available': 3,
#  'Middle': 1,
#  'scripts': 1,
#  'treatise': 2,
#  'Khosrow': 1,
#  'Ridag': 1,
#  'points': 1,
#  'stews': 2,
#  'foods': 3,
#  'way': 1,
#  'using': 4,
#  'obtained': 1,
#  'Sassanid': 1,
#  'period': 2,
#  'valid': 1,
#  'references': 2,
#  'compiling': 1,
#  'cooking': 7,
#  'names': 2,
#  'many': 3,
#  'terms': 1,
#  'translated': 1,
#  'seen': 1,
#  'Arabic': 2,
#  'language': 2,
#  'books': 1,
#  'Naturally': 1,
#  'customs': 1,
#  'habits': 1,
#  'Arabs': 1,
#  'influenced': 2,
#  'Iranians': 5,
#  'specifically': 2,
#  'Abbasid': 2,
#  'period.Ancient': 1,
#  'philosophers': 1,
#  'physicians': 1,
#  'preparation': 4,
#  'follow': 1,
#  'rules': 1,
#  'strengthening': 1,
#  'weakening': 1,
#  'characteristics': 1,
#  'based': 1,
#  'traditional': 15,
#  'medicine': 1,
#  'Although': 1,
#  'cookbooks': 2,
#  'written': 4,
#  'Caliphate—one': 1,
#  'Arab': 1,
#  'caliphates': 1,
#  'ruled': 1,
#  'invasion—include': 1,
#  'recipes': 3,
#  'earliest': 1,
#  'surviving': 3,
#  'classical': 1,
#  'two': 3,
#  'volumes': 1,
#  'Safavid': 4,
#  'older': 1,
#  'entitled': 2,
#  'Manual': 1,
#  'craft': 1,
#  'Kār-nāmeh': 1,
#  'dar': 2,
#  'bāb': 1,
#  'e': 7,
#  'tabbāxī': 1,
#  'va': 1,
#  'sanat': 1,
#  'ān': 1,
#  '927/1521': 1,
#  'aristocratic': 2,
#  'patron': 1,
#  'end': 3,
#  'reign': 1,
#  'Ismail': 1,
#  'I': 2,
#  'book': 3,
#  'originally': 1,
#  'contained': 1,
#  '26': 2,
#  'chapters': 3,
#  'listed': 3,
#  'author': 2,
#  'introduction': 3,
#  '23': 1,
#  'missing': 1,
#  'manuscript': 1,
#  'include': 7,
#  'measurements': 2,
#  'ingredients—often': 1,
#  'detailed': 2,
#  'directions': 2,
#  'types': 5,
#  'utensils': 1,
#  'pots': 1,
#  'used—and': 1,
#  'instructions': 1,
#  'decorating': 1,
#  'serving': 2,
#  'In': 6,
#  'general': 1,
#  'ingredients': 4,
#  'differ': 1,
#  'use': 5,
#  'today': 1,
#  'large': 3,
#  'quantities': 1,
#  'specified': 1,
#  'well': 6,
#  'generous': 1,
#  'luxury': 1,
#  'suggest': 1,
#  'prepared': 5,
#  'households': 1,
#  'even': 1,
#  'though': 3,
#  'claimed': 1,
#  'benefit': 1,
#  'nobility': 1,
#  'public': 1,
#  'second': 1,
#  'cookbook': 1,
#  'substance': 1,
#  'life': 1,
#  'art': 1,
#  'Māddat': 1,
#  'al-ḥayāt': 1,
#  'resāla': 1,
#  'ʿelm': 1,
#  'ṭabbāxī': 1,
#  '76': 1,
#  'years': 1,
#  'later': 1,
#  'chef': 2,
#  'Abbas': 1,
#  'includes': 6,
#  'elaborate': 1,
#  'praise': 1,
#  'God': 1,
#  'prophets': 1,
#  'imams': 1,
#  'shah': 1,
#  'definition': 1,
#  'master': 1,
#  'It': 4,
#  'followed': 1,
#  'six': 1,
#  'four': 1,
#  'qalya': 1,
#  'āsh': 5,
#  'earlier': 1,
#  'information': 1,
#  'provided': 1,
#  'royal': 1,
#  'court': 2,
#  'created': 1,
#  'improved': 1,
#  'shahs': 1,
#  'Other': 3,
#  'contemporary': 1,
#  'cooks': 1,
#  'specialties': 1,
#  'mentioned': 1,
#  'first': 3,
#  'specialty': 3,
#  'evolved': 1,
#  '16th': 1,
#  'century': 2,
#  'CE': 1,
#  'major': 4,
#  'branch': 1,
#  'cookery': 1,
#  'Traditionally': 1,
#  'prevalent': 1,
#  'staple': 2,
#  'item': 1,
#  'northern': 2,
#  'homes': 2,
#  'wealthy': 1,
#  'bread': 5,
#  'dominant': 1,
#  'rest': 1,
#  'country.Varieties': 1,
#  'gerde': 1,
#  'domsia': 1,
#  'literally': 2,
#  'meaning': 2,
#  'black-tail': 1,
#  'black': 2,
#  'champa': 1,
#  'doodi': 2,
#  'smoked': 2,
#  'Lenjan': 2,
#  'County': 2,
#  'Tarom': 2,
#  'anbarbu.The': 1,
#  'following': 10,
#  'table': 7,
#  'three': 2,
#  'primary': 1,
#  'methods': 2,
#  'Iran.Iranian-style': 1,
#  'rice-cookingSoaking': 1,
#  'potUsing': 1,
#  'potatoes': 2,
#  'tahdig': 1,
#  'chelow-style': 1,
#  'rice-cookingPotato': 1,
#  'tahdigTahdig': 1,
#  'lavash': 1,
#  'breadSecond': 1,
#  'production': 2,
#  'wheat': 3,
#  'lists': 4,
#  'several': 11,
#  'forms': 6,
#  'flatbread': 1,
#  'pastry': 2,
#  'commonly': 5,
#  'cuisine.The': 1,
#  'agriculture': 1,
#  'produces': 1,
#  'Thus': 1,
#  'bowl': 1,
#  'fresh': 5,
#  'fruit': 4,
#  'tables': 1,
#  'standard': 1,
#  'side': 2,
#  'meals': 1,
#  'These': 1,
#  'enjoyed': 1,
#  'ripe': 1,
#  'desserts': 5,
#  'combined': 1,
#  'accompaniments': 1,
#  'When': 2,
#  'variety': 10,
#  'dates': 2,
#  'figs': 1,
#  'peaches': 1,
#  'served': 9,
#  'instead': 2,
#  'Southern': 1,
#  'date': 2,
#  'producers': 2,
#  'special': 2,
#  'cultivars': 1,
#  'Bam': 1,
#  'grown.Vegetables': 1,
#  'pumpkins': 1,
#  'spinach': 2,
#  'green': 2,
#  'beans': 5,
#  'fava': 1,
#  'courgette': 1,
#  'varieties': 1,
#  'squash': 2,
#  'onion': 1,
#  'garlic': 2,
#  'carrot': 1,
#  'Tomatoes': 1,
#  'cucumbers': 1,
#  'scallion': 1,
#  'often': 2,
#  'accompany': 1,
#  'meal': 4,
#  'While': 2,
#  'eggplant': 1,
#  'potato': 1,
#  'fond': 1,
#  'salads': 2,
#  'dressed': 1,
#  'olive': 1,
#  'oil': 1,
#  'lemon': 2,
#  'juice': 4,
#  'salt': 1,
#  'chili': 1,
#  'garlic.Fruit': 1,
#  'dolma': 3,
#  'probably': 1,
#  'cooked': 3,
#  'stuffed': 2,
#  'seasonings': 1,
#  'sometimes': 2,
#  'tomato': 3,
#  'sauce': 4,
#  'simmered': 1,
#  'broth': 1,
#  'ascallions': 1,
#  'sweet-and-sour': 1,
#  'Verjuice': 1,
#  'highly': 1,
#  'acidic': 1,
#  'pressing': 1,
#  'unripe': 1,
#  'grapes': 3,
#  'mainly': 1,
#  'within': 3,
#  'soup': 12,
#  'stew': 8,
#  'simmer': 1,
#  'type': 6,
#  'Unripe': 1,
#  'whole': 1,
#  'khoresh-e': 1,
#  'ghooreh': 2,
#  'lamb': 2,
#  'As': 1,
#  'spice': 3,
#  'verjuice': 2,
#  'powder': 2,
#  'pudr-e': 1,
#  'reinforced': 1,
#  'dried.Advieh': 1,
#  'chāshni': 1,
#  'refers': 1,
#  'wide': 2,
#  'pungent': 1,
#  'flavor': 1,
#  'food.One': 1,
#  'widespread': 1,
#  'derived': 1,
#  'flower': 1,
#  'Crocus': 1,
#  'sativus': 1,
#  'Rose': 1,
#  'water': 4,
#  'flavored': 3,
#  'steeping': 1,
#  'rose': 2,
#  'petals': 1,
#  'ingredient': 1,
#  'dishes.Persian': 1,
#  'hogweed': 1,
#  'golpar': 1,
#  'grows': 1,
#  'wild': 1,
#  'humid': 1,
#  'mountainous': 1,
#  'soups': 1,
#  'vinegar': 1,
#  'broad': 1,
#  'dipped': 1,
#  'eating.Some': 1,
#  'seeds': 3,
#  'Elettaria': 1,
#  'Amomum': 1,
#  'plants': 1,
#  ';': 6,
#  'shevid': 1,
#  'annual': 1,
#  'herb': 1,
#  'celery': 1,
#  'family': 1,
#  'Apiaceae': 1,
#  'mahleb': 1,
#  'aromatic': 1,
#  'Prunus': 1,
#  'mahaleb': 1,
#  'limu': 1,
#  'amani': 1,
#  'lime.There': 1,
#  'arde': 1,
#  'Tahini': 1,
#  'toasted': 1,
#  'ground': 2,
#  'hulled': 1,
#  'sesame': 1,
#  'delal': 1,
#  'heavily': 1,
#  'salted': 1,
#  'herbs': 5,
#  'cilantro': 1,
#  'parsley.Typical': 1,
#  'kebab': 4,
#  'pilaf': 3,
#  'pastries': 1,
#  'drinks.In': 1,
#  'kebabs': 1,
#  'either': 4,
#  'A': 4,
#  'dish': 12,
#  'chelow': 2,
#  'white': 3,
#  'called': 9,
#  'kabab': 2,
#  'considered': 1,
#  'national': 1,
#  'kateh': 2,
#  'method': 3,
#  'hence': 1,
#  'would': 1,
#  'kebab.The': 1,
#  'cuisine.Khoresh': 1,
#  'form': 2,
#  'usually': 7,
#  'accompanied': 3,
#  'plate': 1,
#  'khoresh': 3,
#  'typically': 6,
#  'consists': 3,
#  'pieces': 1,
#  'paste': 2,
#  'pomegranate': 2,
#  'non-khoresh': 1,
#  'dizi': 1,
#  'rice.Several': 1,
#  'table.There': 1,
#  'sup': 3,
#  'jow': 1,
#  'barley': 1,
#  'esfenaj': 1,
#  'qarch': 1,
#  'mushroom': 1,
#  'thick': 2,
#  'referred': 3,
#  'Also': 1,
#  'shole': 1,
#  'qalamkar': 1,
#  'hodge-podge': 1,
#  'mixture': 2,
#  'ingredients.The': 1,
#  'number': 3,
#  'cuisine.Apart': 1,
#  'rice-based': 2,
#  'polow': 4,
#  'dami.Polow': 1,
#  'word': 1,
#  'languages': 1,
#  'English': 1,
#  'may': 1,
#  'variations': 1,
#  'spelling': 1,
#  'cuts': 1,
#  'chicken': 1,
#  'red': 1,
#  'Dami': 1,
#  'similar': 2,
#  'involve': 1,
#  'however': 1,
#  'dami': 1,
#  'pot.The': 1,
#  '400': 1,
#  'BC': 1,
#  'ancient': 1,
#  'invented': 1,
#  'chilled': 1,
#  'food': 6,
#  'vermicelli': 1,
#  'royalty': 1,
#  'summertime': 1,
#  'ice': 4,
#  'flavors': 1,
#  'Today': 1,
#  'famous': 2,
#  'semi-frozen': 1,
#  'noodle': 1,
#  'dessert': 2,
#  'faloodeh': 1,
#  'roots': 1,
#  'city': 3,
#  'Shiraz': 3,
#  'former': 1,
#  'capital': 2,
#  'country': 1,
#  'Bastani': 1,
#  'zaferani': 1,
#  'cream': 4,
#  'typical': 1,
#  'dairy': 2,
#  'desserts.The': 1,
#  'list': 1,
#  'desserts.Cookies': 1,
#  'appear': 1,
#  'origins': 1,
#  '7th-century': 1,
#  'shortly': 1,
#  'sugar': 3,
#  'became': 1,
#  'relatively': 1,
#  'region': 13,
#  'There': 2,
#  'numerous': 1,
#  'native': 1,
#  'snack': 1,
#  'modern': 1,
#  'table.Iran': 1,
#  'tea': 3,
#  '[': 2,
#  'better': 1,
#  'source': 1,
#  'mostly': 2,
#  'cultivated': 2,
#  'culture': 2,
#  'čāy': 1,
#  'widely': 3,
#  'thing': 1,
#  'offered': 1,
#  'guest': 1,
#  'traditionally': 2,
#  'put': 1,
#  'lump': 1,
#  'cube': 1,
#  'mouth': 1,
#  'drinking': 1,
#  'Rock': 1,
#  'candies': 1,
#  'saffron.Iran': 1,
#  'coffee': 4,
#  'qahve': 1,
#  'kāfe': 1,
#  'sweet': 1,
#  'booby-trapped': 1,
#  'sediment': 1,
#  'grounds': 1,
#  '16th-century': 1,
#  'initially': 1,
#  'medical': 1,
#  'purposes': 1,
#  'among': 2,
#  'society': 1,
#  'Traditional': 1,
#  'coffeehouses': 1,
#  'popular': 6,
#  'gatherings': 1,
#  'people': 3,
#  'drank': 1,
#  'tobacco': 1,
#  'recited': 1,
#  'poetry—especially': 1,
#  'epic': 1,
#  'poems': 1,
#  'Shahnameh': 1,
#  'present-day': 1,
#  'cafés': 1,
#  'trendy': 1,
#  'urban': 1,
#  'areas': 1,
#  'brews': 1,
#  'Azeris': 1,
#  'Wine': 1,
#  'mey': 1,
#  'Shirazi': 1,
#  'wine': 4,
#  'originating': 1,
#  'By': 1,
#  '9th': 1,
#  'already': 1,
#  'established': 1,
#  'reputation': 1,
#  'producing': 1,
#  'finest': 1,
#  'Since': 2,
#  '1979': 3,
#  'Revolution': 3,
#  'alcoholic': 4,
#  'beverages': 4,
#  'prohibited': 1,
#  'non-Muslim': 1,
#  'recognized': 1,
#  'minorities': 1,
#  'i.e': 1,
#  'Christians': 1,
#  'Jews': 1,
#  'Zoroastrians': 1,
#  'allowed': 1,
#  'produce': 1,
#  'non-alcoholic': 1,
#  'beer': 1,
#  'ābjow': 1,
#  'legal': 1,
#  'outlets': 1,
#  'citizens': 1,
#  'prepare': 1,
#  'illegally': 1,
#  'minority': 1,
#  'largely': 1,
#  'Iraqi': 1,
#  'Kurdistan': 2,
#  'Turkey': 2,
#  'Araq': 1,
#  'sagi': 1,
#  'doggy': 1,
#  'distillate': 1,
#  'distilled': 1,
#  'beverage': 1,
#  'contains': 2,
#  'least': 1,
#  '65': 1,
#  '%': 1,
#  'pure': 1,
#  'ethanol': 1,
#  'produced': 2,
#  'rakı': 1,
#  'Prior': 1,
#  'outlawed': 1,
#  'become': 1,
#  'market': 1,
#  'underground': 1,
#  'business.The': 1,
#  'cold': 2,
#  'beverages.The': 1,
#  'Azerbaijani': 1,
#  'living': 1,
#  'primarily': 2,
#  'Azerbaijan': 1,
#  'northwestern': 1,
#  'local': 5,
#  'Bonab': 1,
#  'Binab': 1,
#  'kababı': 1,
#  'dumpling': 1,
#  'joshpara': 1,
#  'düşbərə': 1,
#  'offal-based': 1,
#  'named': 1,
#  'jaqul': 1,
#  'baqul': 1,
#  'containing': 2,
#  'liver': 1,
#  'heart': 1,
#  'kələcoş': 1,
#  'variation': 3,
#  'qeyme': 1,
#  'pıçaq': 1,
#  'kufte': 2,
#  'Tabriz': 1,
#  'meatballs': 1,
#  'shekerbura': 1,
#  'şəkərbura': 1,
#  'identical': 1,
#  'Khorasan': 2,
#  'shekarpare': 1,
#  'šekarpāre': 1,
#  'Despite': 1,
#  'influences': 1,
#  'tastes': 1,
#  'noticeably': 1,
#  'unique': 2,
#  'features': 1,
#  'butter': 2,
#  'Meat': 1,
#  'southeastern': 1,
#  'Baluchistan': 2,
#  'Rice': 1,
#  'Makran': 1,
#  'Foods': 1,
#  'specific': 1,
#  'tanurche': 1,
#  'tarōnča': 1,
#  'tanurče': 1,
#  'grilled': 2,
#  'tanur': 1,
#  'doogh-pa': 1,
#  'dōq-pâ': 1,
#  'doogh': 1,
#  'tabahag': 1,
#  'tabâhag': 1,
#  'Baluchi': 1,
#  'date-based': 1,
#  'southern': 3,
#  'coast': 1,
#  'Caspian': 2,
#  'Sea': 1,
#  'provinces': 2,
#  'Gilan': 2,
#  'Mazanderan': 1,
#  'Alborz': 1,
#  'Golestan': 2,
#  'fertile': 1,
#  'environment': 1,
#  'reflected': 1,
#  'Kateh': 1,
#  'originates': 1,
#  'This': 1,
#  'eaten': 6,
#  'breakfast': 3,
#  'heated': 1,
#  'milk': 1,
#  'jam': 1,
#  'cheese': 3,
#  'Caviar': 1,
#  'fish': 4,
#  'roes': 1,
#  'hail': 1,
#  'eggs': 1,
#  'frittatas': 1,
#  'omelettesor': 1,
#  'simply': 1,
#  'Lavash': 1,
#  'Butter': 1,
#  'Fish': 1,
#  'province': 1,
#  'Kutum': 1,
#  'Smoked': 1,
#  'ماهی': 1,
#  'دودی': 1,
#  'Romanized': 1,
#  'Mahi': 1,
#  'incorporated': 1,
#  'steaming': 1,
#  'together': 1,
#  'Local': 1,
#  'cookies': 1,
#  'koluče': 1,
#  'desert': 1,
#  'items': 1,
#  'particularly': 1,
#  'Fuman': 1,
#  'Another': 1,
#  'Reshteh': 1,
#  'Khoshkar': 1,
#  'رشته': 1,
#  'خشکار': 1,
#  'consisting': 1,
#  'fried': 1,
#  'flour': 1,
#  'dough': 1,
#  'filled': 1,
#  'Medlar': 1,
#  'locally': 1,
#  'Konos': 1,
#  'کونوس': 1,
#  '.The': 1,
#  'western': 1,
#  'home': 1,
#  'Some': 1,
#  'Kurdish': 1,
#  'rib': 1,
#  'dande': 1,
#  'kabāb': 1,
#  'chives': 1,
#  'xoreš-e': 1,
#  'tare': 1,
#  'sib': 1,
#  'spicy': 1,
#  'Mahyawa': 1,
#  'tangy': 1,
#  'fermented': 1,
#  'citation': 1,
#  'Being': 1,
#  'coastal': 1,
#  'Khuzestan': 2,
#  'seafood': 1,
#  'kibbeh': 1,
#  'cracked': 1,
#  'different': 1,
#  'spices.Iran': 1,
#  'Turkmen': 2,
#  'predominantly': 1,
#  'centered': 1,
#  'North': 1,
#  'Chegderme': 1,
#  'čekderme': 1,
#  'basic': 1,
#  'flat': 2,
#  'breads': 2,
#  'cubes': 1,
#  'whipped': 1,
#  'heavy': 1,
#  'sarshir': 1,
#  'sweetened': 1,
#  'honey': 1,
#  'walnuts': 1,
#  'jams': 1,
#  'spreads.Many': 1,
#  'towns': 1,
#  'across': 1,
#  'feature': 1,
#  'distinct': 1,
#  'versions': 1,
#  'Pache': 1,
#  'neighboring': 1,
#  'Caucasus': 1,
#  'almost': 1,
#  'always': 1,
#  'morning': 1,
#  'sometime': 1,
#  'dawn': 1,
#  'restaurants': 1,
#  'pache': 1,
#  'open': 1,
#  'hours.Traditional': 1,
#  'done': 1,
#  'stages': 1,
#  'times': 1,
#  'needing': 1,
#  'hours': 1,
#  'attention': 1,
#  'outcome': 1,
#  'well-balanced': 1,
#  'products': 1,
#  'Major': 1,
#  'staples': 1,
#  'every': 1,
#  'poultry': 1,
#  'beef': 1,
#  'Stew': 1,
#  'far': 1,
#  'constitution': 1,
#  'vary': 1,
#  'region.Traditional': 1,
#  'setting': 1,
#  'firstly': 1,
#  'involves': 1,
#  'tablecloth': 1,
#  'sofre': 2,
#  'spread': 1,
#  'rug': 1,
#  'Main': 1,
#  'concentrated': 1,
#  'middle': 1,
#  'surrounded': 1,
#  'smaller': 1,
#  'appetizers': 1,
#  'condiments': 1,
#  'nearest': 1,
#  'diners': 1,
#  'perfectly': 1,
#  'invitation': 1,
#  'seat': 1,
#  'start': 1}

# %% [markdown]
# #### <font color="#fd79a8"> Fréquence pondérée de chaque mots

# %%
# Fréquence maximale
maximum_frequency = max(word_frequencies.values())
# Calculer la fréquence pondérée
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word] / maximum_frequency

# %%
# afficher word_frequencies
word_frequencies
# Out:
# {'Iranian': 0.20512820512820512,
#  'cuisine': 0.09829059829059829,
#  '(': 0.14957264957264957,
#  'Persian': 0.042735042735042736,
#  ':': 0.03418803418803419,
#  'آشپزی': 0.004273504273504274,
#  'ایرانی': 0.004273504273504274,
#  ',': 1.0,
#  'romanized': 0.004273504273504274,
#  'Āshpazī': 0.004273504273504274,
#  'Irānī': 0.004273504273504274,
#  ')': 0.14957264957264957,
#  'culinary': 0.01282051282051282,
#  'traditions': 0.008547008547008548,
#  'Iran': 0.13675213675213677,
#  '.': 0.41452991452991456,
#  'Due': 0.004273504273504274,
#  'historically': 0.008547008547008548,
#  'common': 0.021367521367521368,
#  'usage': 0.008547008547008548,
#  'term': 0.008547008547008548,
#  '``': 0.05128205128205128,
#  'Persia': 0.004273504273504274,
#  "''": 0.042735042735042736,
#  'refer': 0.004273504273504274,
#  'Western': 0.004273504273504274,
#  'world': 0.017094017094017096,
#  'alternatively': 0.004273504273504274,
#  'known': 0.01282051282051282,
#  'despite': 0.004273504273504274,
#  'Persians': 0.004273504273504274,
#  'one': 0.038461538461538464,
#  'multitude': 0.004273504273504274,
#  'ethnic': 0.004273504273504274,
#  'groups': 0.008547008547008548,
#  'contributed': 0.004273504273504274,
#  "'s": 0.04700854700854701,
#  'The': 0.08974358974358974,
#  'made': 0.05982905982905983,
#  'extensive': 0.004273504273504274,
#  'contact': 0.004273504273504274,
#  'throughout': 0.004273504273504274,
#  'history': 0.008547008547008548,
#  'cuisines': 0.004273504273504274,
#  'neighbouring': 0.004273504273504274,
#  'regions': 0.01282051282051282,
#  'including': 0.021367521367521368,
#  'heavy': 0.004273504273504274,
#  'sarshir': 0.004273504273504274,
#  'sweetened': 0.004273504273504274,
#  'honey': 0.004273504273504274,
#  'walnuts': 0.004273504273504274,
#  'jams': 0.004273504273504274,
#  'spreads.Many': 0.004273504273504274,
#  'towns': 0.004273504273504274,
#  'across': 0.004273504273504274,
#  'feature': 0.004273504273504274,
#  'distinct': 0.004273504273504274,
#  'versions': 0.004273504273504274,
#  'Pache': 0.004273504273504274,
#  'neighboring': 0.004273504273504274,
#  'Caucasus': 0.004273504273504274,
#  'almost': 0.004273504273504274,
#  'always': 0.004273504273504274,
#  'morning': 0.004273504273504274,
#  'sometime': 0.004273504273504274,
#  'dawn': 0.004273504273504274,
#  'restaurants': 0.004273504273504274,
#  'pache': 0.004273504273504274,
#  'open': 0.004273504273504274,
#  'hours.Traditional': 0.004273504273504274,
#  'done': 0.004273504273504274,
#  'stages': 0.004273504273504274,
#  'times': 0.004273504273504274,
#  'needing': 0.004273504273504274,
#  'hours': 0.004273504273504274,
#  'attention': 0.004273504273504274,
#  'outcome': 0.004273504273504274,
#  'well-balanced': 0.004273504273504274,
#  'products': 0.004273504273504274,
#  'Major': 0.004273504273504274,
#  'staples': 0.004273504273504274,
#  'every': 0.004273504273504274,
#  'poultry': 0.004273504273504274,
#  'beef': 0.004273504273504274,
#  'Stew': 0.004273504273504274,
#  'far': 0.004273504273504274,
#  'constitution': 0.004273504273504274,
#  'vary': 0.004273504273504274,
#  'region.Traditional': 0.004273504273504274,
#  'setting': 0.004273504273504274,
#  'firstly': 0.004273504273504274,
#  'involves': 0.004273504273504274,
#  'tablecloth': 0.004273504273504274,
#  'sofre': 0.008547008547008548,
#  'spread': 0.004273504273504274,
#  'rug': 0.004273504273504274,
#  'Main': 0.004273504273504274,
#  'concentrated': 0.004273504273504274,
#  'middle': 0.004273504273504274,
#  'surrounded': 0.004273504273504274,
#  'smaller': 0.004273504273504274,
#  'appetizers': 0.004273504273504274,
#  'condiments': 0.004273504273504274,
#  'nearest': 0.004273504273504274,
#  'diners': 0.004273504273504274,
#  'perfectly': 0.004273504273504274,
#  'invitation': 0.004273504273504274,
#  'seat': 0.004273504273504274,
#  'start': 0.004273504273504274}

# %% [markdown]
# #### <font color="#fd79a8"> Score des phrases

# %%
# Liste des scores de chaque phrase
sentence_scores = {}
# Calculer le score de chaque phrase
for sent in sentence_list:
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
# Afficher sentences scores
sentence_scores
# Out:
# {'Iranian cuisine (Persian: آشپزی ایرانی, romanized: Āshpazī Irānī) are the culinary traditions of Iran.': 1.9145299145299144,
#  'Typical Iranian main dishes are combinations of rice with meat, vegetables and nuts.': 1.7777777777777777,
#  'Herbs are frequently used, along with fruits such as plums, pomegranates, quince, prunes, apricots and raisins.': 5.576923076923077,
#  'The names of many of the Iranian dishes and culinary terms that have been translated can be seen in Arabic language books.': 0.5982905982905984,
#  'The book originally contained 26 chapters, listed by the author in his introduction, but chapters 23 through 26 are missing from the surviving manuscript.': 2.538461538461538,
#  'The recipes include measurements for ingredients—often detailed directions for the preparation of dishes, including the types of utensils and pots to be used—and instructions for decorating and serving them.': 1.7008547008547006,
#  'In general, the ingredients and their combinations in various recipes do not differ significantly from those in use today.': 1.5641025641025639,
#  'The introduction of that book includes elaborate praise of God, the prophets, the imams, and the shah, as well as a definition of a master chef.': 4.52991452991453,
#  'It is followed by six chapters on the preparation of various dishes: four on rice dishes, one on qalya, and one on āsh.': 3.0170940170940166,
#  'The measurements and directions are not as detailed as in the earlier book.': 0.4572649572649573,
#  'The information provided is about dishes prepared at the royal court, including references to a few that had been created or improved by the shahs themselves.': 1.623931623931624,
#  'Other contemporary cooks and their specialties are also mentioned.': 0.5299145299145299,
#  'The following table lists several forms of flatbread and pastry bread commonly used in Iranian cuisine.The agriculture of Iran produces many fruits and vegetables.': 0.7735042735042735,
#  'Thus, a bowl of fresh fruit is common on Iranian tables, and vegetables are standard side dishes in most meals.': 2.6538461538461533,
#  'These are not only enjoyed fresh and ripe as desserts but are also combined with meat as accompaniments to main dishes.': 0.764957264957265,
#  'When fresh fruits are not available, a large variety of dried fruits such as dates, figs, apricots, plums and peaches are served instead.': 4.670940170940171,
#  'Tomatoes, cucumbers and scallion often accompany a meal.': 1.452991452991453,
#  'The fruit is first cooked, then stuffed with meat, seasonings, and sometimes tomato sauce.': 3.564102564102564,
#  'The dolma is then simmered in meat broth or ascallions sweet-and-sour sauce.': 0.5170940170940171,
#  'Verjuice, a highly acidic juice made by pressing unripe grapes or other sour fruit, is used in various Iranian dishes.': 2.8034188034188023,
#  'It is mainly used within soup and stew dishes, but also to simmer a type of squash dolma.': 1.846153846153846,
#  'Unripe grapes are also used whole in some dishes such as khoresh-e ghooreh (lamb stew with sour grapes).': 1.0940170940170941,
#  'A dish of chelow white rice with kebab is called chelow kabab, which is considered the national dish of Iran.': 1.7307692307692308,
#  'A khoresh typically consists of herbs, fruits, and meat pieces, flavored with tomato paste, saffron, and pomegranate juice.': 5.666666666666666,
#  'A thick soup is referred to as āsh in Iran, which is an Iranian traditional form of soup.': 1.6324786324786327,
#  'A polow dish includes rice stuffed with cuts of vegetables, fruits, and beans, usually accompanied by either chicken or red meat.': 3.841880341880341,
#  'The ice was mixed with saffron, fruits, and various other flavors.': 2.572649572649573,
#  'Bastani e zaferani, Persian for "saffron ice cream", is a traditional Iranian ice cream which is also commonly referred to as "the traditional ice cream".': 3.025641025641025,
#  'In Iranian culture, tea (čāy) is widely    and is typically the first thing offered to a guest.': 1.803418803418803,
#  'Iranians traditionally put a lump of sugar cube in the mouth before drinking the tea.': 0.4700854700854701,
#  'Rock candies are also widely used, typically flavored with saffron.Iran\'s traditional coffee (qahve, or kāfe) is served strong, sweet, and "booby-trapped with a sediment of grounds".': 5.217948717948717,
#  'In 16th-century Safavid Iran, coffee was initially used for medical purposes among the society.': 1.517094017094017,
#  'Traditional coffeehouses were popular gatherings, in which people drank coffee, smoked tobacco, and recited poetry—especially the epic poems of Shahnameh.': 3.5769230769230766,
#  'In present-day Iran, cafés are trendy mostly in urban areas, where a variety of brews and desserts are served.': 2.5512820512820507,
#  'Turkish coffee is also popular in Iran, more specifically among Iranian Azeris.': 1.5726495726495726,
#  'Wine (mey) has also a significant presence in Iranian culture.': 0.858974358974359,
#  "Shirazi wine is Iran's historically most famous wine production, originating from the city of Shiraz.": 1.5384615384615385,
#  "By the 9th century, the city of Shiraz had already established a reputation for producing the finest wine in the world,  and was Iran's wine capital.": 2.5683760683760677,
#  'Since the 1979 Revolution, alcoholic beverages have been prohibited in Iran; though non-Muslim recognized minorities (i.e.': 1.6666666666666663,
#  'Christians, Jews, and Zoroastrians) are allowed to produce alcoholic beverages for their own use.': 2.6282051282051277,
#  'Araq sagi, literally meaning "doggy distillate", is a type of distilled alcoholic beverage in Iran which contains at least 65% pure ethanol.': 2.6196581196581192,
#  'It is usually produced at homes from raisins, and is similar to Turkish rakı.': 1.482905982905983,
#  'Prior to the 1979 Revolution, it had been produced traditionally in several cities of Iran.': 1.5042735042735043,
#  "There is also the traditional pastry of shekerbura (şəkərbura), which is identical to Khorasan's shekarpare (šekarpāre).": 2.252136752136752,
#  "Meat and dates are the main ingredients in the cuisine of Iran's southeastern region of Baluchistan.": 0.7136752136752137,
#  'Rice is primarily cultivated in the region of Makran.': 0.5982905982905983,
#  'Baluchi cuisine also includes several date-based dishes, as well as various types of bread.': 1.9444444444444442,
#  'Kateh is a method of cooking rice that originates from this region.': 0.6367521367521367,
#  'This type of rice dish is also eaten there as a breakfast meal, either heated with milk and jam or cold with cheese and garlic.': 1.8162393162393162,
#  'Caviar fish roes also hail from this region, and are typically served with eggs in frittatas and omelettesor eaten simply with Lavash and Butter.': 1.7136752136752136,
#  'Fish is commonly eaten in the Gilan province, where Caspian Kutum is a   and usually served   along with rice.': 1.670940170940171,
#  'Smoked fish (Persian: ماهی دودی, Romanized: Mahi doodi) is also popular in   and usually incorporated into rice by steaming the two together.': 2.1196581196581197,
#  'Local cookies (koluče) of the region are popular desert items,  particularly those from the region of Fuman.': 1.893162393162393,
#  'Another notable dessert from this region is Reshteh Khoshkar (Persian: رشته خشکار), consisting of fried rice flour dough filled with sugar and nuts.': 1.987179487179487,
#  'The food of southern Iran is typically spicy.': 0.4829059829059829,
#  'Mahyawa is a tangy sauce made of fermented fish in this region.': 0.5726495726495726,
#  "[citation   Being a coastal region, Khuzestan's cuisine includes especially seafood, as well as some unique local beverages.": 2.7478632478632474,
#  'Chegderme (čekderme) is a Turkmen dish made of rice, meat, and tomato paste.': 3.0170940170940166,
#  'The outcome is a well-balanced mixture of herbs, meat, beans, dairy products, and vegetables.': 4.572649572649572,
#  'Main dishes are concentrated in the middle, surrounded by smaller dishes containing appetizers, condiments, and side dishes, all of which are nearest to the diners.': 4.850427350427351,
#  'When the food is perfectly served, an invitation is made to seat at the sofre and start having the meal.': 1.5811965811965811}

# %% [markdown]
# #### <font color="#fd79a8"> Résumé de l'article

# %%
def summarizer(text, num_sentences=10):

# Ordonner les phrases par pondération et recupérer les 10 premières phrases
    summary_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=False)[:10]
    # regrouper ensemble les phrases qui ont les poids les plus élévés
    summary = ' '.join(summary_sentences)

    # Afficher le résumé
    return summary_sentences
# Out:
# ['The measurements and directions are not as detailed as in the earlier book.',
#  'Iranians traditionally put a lump of sugar cube in the mouth before drinking the tea.',
#  'The food of southern Iran is typically spicy.',
#  'The dolma is then simmered in meat broth or ascallions sweet-and-sour sauce.',
#  'Other contemporary cooks and their specialties are also mentioned.',
#  'Mahyawa is a tangy sauce made of fermented fish in this region.',
#  'Rice is primarily cultivated in the region of Makran.',
#  'The names of many of the Iranian dishes and culinary terms that have been translated can be seen in Arabic language books.',
#  'Kateh is a method of cooking rice that originates from this region.',
#  "Meat and dates are the main ingredients in the cuisine of Iran's southeastern region of Baluchistan."]

# %% [markdown]
# ## <font color="#F0000"> Text summarization avec sumy

# %%
# Importer les packages
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer

# Créer un text parser utilisant de tokenisation
parser = PlaintextParser.from_string(article_text, Tokenizer('english'))

# %%
parser.document.sentences
# Out:
# (<Sentence: Iranian cuisine (Persian: آشپزی ایرانی, romanized: Āshpazī Irānī) are the culinary traditions of Iran.>,
#  <Sentence: Due to the historically common usage of the term "Persia" to refer to Iran in the Western world,    it is alternatively known as Persian cuisine, despite Persians being only one of a multitude of Iranian ethnic groups who have contributed to Iran's culinary traditions.>,
#  <Sentence: The cuisine of Iran has made extensive contact throughout its history with the cuisines of its neighbouring regions, including Caucasian cuisine, Central Asian cuisine, Greek cuisine, Levantine cuisine, Mesopotamian cuisine, Russian cuisine and Turkish cuisine.>,
#  <Sentence: Aspects of Iranian cuisine have also been significantly adopted by Indian cuisine and Pakistani cuisine through various historical Persianate sultanates that flourished during Muslim rule on the Indian subcontinent, with the most notable and impactful of these polities being the Mughal Empire.>,
#  <Sentence: Typical Iranian main dishes are combinations of rice with meat, vegetables and nuts.>,
#  <Sentence: Herbs are frequently used, along with fruits such as plums, pomegranates, quince, prunes, apricots and raisins.>,
#  <Sentence: Characteristic Iranian spices and flavourings such as saffron, cardamom, and dried lime and other sources of sour flavoring, cinnamon, turmeric and parsley are mixed and used in various dishes.Outside of Iran, a strong presence of Iranian cuisine can be found in cities with significant Iranian diaspora populations, namely the San Francisco Bay Area, Vancouver, Toronto,     Houston and especially Los Angeles and its environs.>,
#  <Sentence: Among the writings available from the Middle Persian scripts, the treatise of Khosrow and Ridag, points about stews and foods and the way of using them and how they are obtained in the Sassanid period are found as valid references in compiling the history of cooking in Iran.>,
#  <Sentence: The names of many of the Iranian dishes and culinary terms that have been translated can be seen in Arabic language books.>,
#  <Sentence: Naturally the customs and habits of the Arabs influenced the Iranians, specifically in Abbasid period.Ancient Persian philosophers and physicians have influenced the preparation of Iranian foods to follow the rules of the strengthening and weakening characteristics of foods based on the Iranian traditional medicine.>,
#  <Sentence: Although the Arabic cookbooks written under the rule of the Abbasid Caliphate—one of the Arab caliphates which ruled Iran after the Muslim invasion—include some recipes with Iranian names, the earliest surviving classical cookbooks in Persian are two volumes from the Safavid period.>,
#  <Sentence: The older one is entitled "Manual on cooking and its craft" (Kār-nāmeh dar bāb e tabbāxī va sanat e ān) written in 927/1521 for an aristocratic patron at the end of the reign of Ismail I.>,
#  <Sentence: The book originally contained 26 chapters, listed by the author in his introduction, but chapters 23 through 26 are missing from the surviving manuscript.>,
#  <Sentence: The recipes include measurements for ingredients—often detailed directions for the preparation of dishes, including the types of utensils and pots to be used—and instructions for decorating and serving them.>,
#  <Sentence: In general, the ingredients and their combinations in various recipes do not differ significantly from those in use today.>,
#  <Sentence: The large quantities specified, as well as the generous use of such luxury ingredients as saffron, suggest that these dishes were prepared for large aristocratic households, even though in his introduction, the author claimed to have written it "for the benefit of the nobility, as well as the public.>,
#  <Sentence: "The second surviving Safavid cookbook, entitled "The substance of life, a treatise on the art of cooking" (Māddat al-ḥayāt, resāla dar ʿelm e ṭabbāxī), was written about 76 years later by a chef for Abbas I.>,
#  <Sentence: The introduction of that book includes elaborate praise of God, the prophets, the imams, and the shah, as well as a definition of a master chef.>,
#  <Sentence: It is followed by six chapters on the preparation of various dishes: four on rice dishes, one on qalya, and one on āsh.>,
#  <Sentence: The measurements and directions are not as detailed as in the earlier book.>,
#  <Sentence: The information provided is about dishes prepared at the royal court, including references to a few that had been created or improved by the shahs themselves.>,
#  <Sentence: Other contemporary cooks and their specialties are also mentioned.>,
#  <Sentence: The usage of rice, at first a specialty of the Safavid Empire's court cuisine, evolved by the end of the 16th century CE into a major branch of Iranian cookery.>,
#  <Sentence: Traditionally, rice was most prevalent as a major staple item in northern Iran and the homes of the wealthy, while bread was the dominant staple in the rest of the country.Varieties of rice in Iran include gerde, domsia (literally meaning black-tail, because it is black at one end), champa, doodi (smoked rice), Lenjan (from Lenjan County), Tarom (from Tarom County), and anbarbu.The following table includes three primary methods of cooking rice in Iran.Iranian-style rice-cookingSoaking rice in a potUsing potatoes as tahdig in chelow-style rice-cookingPotato tahdigTahdig of lavash breadSecond only to rice is the production and use of wheat.>,
#  <Sentence: The following table lists several forms of flatbread and pastry bread commonly used in Iranian cuisine.The agriculture of Iran produces many fruits and vegetables.>,
#  <Sentence: Thus, a bowl of fresh fruit is common on Iranian tables, and vegetables are standard side dishes in most meals.>,
#  <Sentence: These are not only enjoyed fresh and ripe as desserts but are also combined with meat as accompaniments to main dishes.>,
#  <Sentence: When fresh fruits are not available, a large variety of dried fruits such as dates, figs, apricots, plums and peaches are served instead.>,
#  <Sentence: Southern Iran is one of the world's major date producers, where some special cultivars such as the Bam date are grown.Vegetables such as pumpkins, spinach, green beans, fava beans, courgette, varieties of squash, onion, garlic and carrot are commonly used in Iranian dishes.>,
#  <Sentence: Tomatoes, cucumbers and scallion often accompany a meal.>,
#  <Sentence: While the eggplant is "the potato of Iran",  Iranians are fond of fresh green salads dressed with olive oil, lemon juice, salt, chili, and garlic.Fruit dolma is probably a specialty of Iranian cuisine.>,
#  <Sentence: The fruit is first cooked, then stuffed with meat, seasonings, and sometimes tomato sauce.>,
#  <Sentence: The dolma is then simmered in meat broth or ascallions sweet-and-sour sauce.>,
#  <Sentence: Verjuice, a highly acidic juice made by pressing unripe grapes or other sour fruit, is used in various Iranian dishes.>,
#  <Sentence: It is mainly used within soup and stew dishes, but also to simmer a type of squash dolma.>,
#  <Sentence: Unripe grapes are also used whole in some dishes such as khoresh-e ghooreh (lamb stew with sour grapes).>,
#  <Sentence: As a spice, verjuice powder (pudr-e ghooreh) is sometimes reinforced by verjuice and then dried.Advieh or chāshni refers to a wide variety of pungent vegetables and dried fruits that are used in Iranian cuisine to flavor food.One of the traditional and most widespread Iranian spices is saffron, derived from the flower of Crocus sativus.>,
#  <Sentence: Rose water, a flavored water made by steeping rose petals in water, is also a traditional and common ingredient in many Iranian dishes.Persian hogweed (golpar), which grows wild in the humid mountainous regions of Iran, is used as a spice in various Iranian soups and stews.>,
#  <Sentence: It is also mixed with vinegar into which broad beans are dipped before eating.Some other common spices are cardamom, made from the seeds of several Elettaria and Amomum plants; shevid, an annual herb in the celery family Apiaceae; mahleb, an aromatic spice made from the seeds of Prunus mahaleb; and limu amani, dried lime.There are also several traditional combinations of spices, two of which are arde (Tahini), made from toasted ground hulled sesame seeds, and delal sauce, made of heavily salted fresh herbs such as cilantro and parsley.Typical Iranian cuisine includes a wide variety of dishes, including several forms of kebab, stew, soup, and pilaf dishes, as well as various salads, desserts, pastries, and drinks.In Iran, kebabs are served either with rice or with bread.>,
#  <Sentence: A dish of chelow white rice with kebab is called chelow kabab, which is considered the national dish of Iran.>,
#  <Sentence: The rice can also be prepared using the kateh method, and hence the dish would be called kateh kebab.The following table lists several forms of kebab used in Iranian cuisine.Khoresh is an Iranian form of stew, which is usually accompanied by a plate of white rice.>,
#  <Sentence: A khoresh typically consists of herbs, fruits, and meat pieces, flavored with tomato paste, saffron, and pomegranate juice.>,
#  <Sentence: Other non-khoresh types of stew such as dizi are accompanied by bread instead of rice.Several Iranian stew dishes are listed within the following table.There are various forms of soup in Iranian cuisine, including sup e jow (barley soup), sup e esfenaj (spinach soup), sup e qarch (mushroom soup), and several forms of thick soup.>,
#  <Sentence: A thick soup is referred to as āsh in Iran, which is an Iranian traditional form of soup.>,
#  <Sentence: Also, shole qalamkar is the Iranian term for "hodge-podge" soup,  a soup made of a mixture of various ingredients.The following table lists a number of soup and āsh dishes in Iranian cuisine.Apart from dishes of rice with kebab or stew, there are various rice-based Iranian dishes cooked in the traditional methods of polow and dami.Polow is the Persian word for pilaf and it is also used in other Iranian languages, in the English language it may have variations in spelling.>,
#  <Sentence: A polow dish includes rice stuffed with cuts of vegetables, fruits, and beans, usually accompanied by either chicken or red meat.>,
#  <Sentence: Dami dishes are similar to polow in that they involve various ingredients with rice, however they are cooked using the dami method of cooking the dish all in one pot.The following are a number of traditional Iranian rice-based dishes:In 400 BC, the ancient Iranians invented a special chilled food, made of rose water and vermicelli, which was served to royalty in summertime.>,
#  <Sentence: The ice was mixed with saffron, fruits, and various other flavors.>,
#  <Sentence: Today, one of the most famous Iranian desserts in the semi-frozen noodle dessert known as faloodeh, which has its roots in the city of Shiraz, a former capital of the country.>,
#  <Sentence: Bastani e zaferani, Persian for "saffron ice cream", is a traditional Iranian ice cream which is also commonly referred to as "the traditional ice cream".>,
#  <Sentence: Other typical Iranian desserts include several forms of rice, wheat and dairy desserts.The following is a list of several Iranian desserts.Cookies appear to have their origins in 7th-century Iran, shortly after the use of sugar became relatively common in the region.>,
#  <Sentence: There are numerous traditional native and adopted types of snack food in modern Iran, of which some are listed within the following table.Iran is one of the world's major tea producers, [better source   mostly cultivated in its northern regions.>,
#  <Sentence: In Iranian culture, tea (čāy) is widely    and is typically the first thing offered to a guest.>,
#  <Sentence: Iranians traditionally put a lump of sugar cube in the mouth before drinking the tea.>,
#  <Sentence: Rock candies are also widely used, typically flavored with saffron.Iran's traditional coffee (qahve, or kāfe) is served strong, sweet, and "booby-trapped with a sediment of grounds".>,
#  <Sentence: In 16th-century Safavid Iran, coffee was initially used for medical purposes among the society.>,
#  <Sentence: Traditional coffeehouses were popular gatherings, in which people drank coffee, smoked tobacco, and recited poetry—especially the epic poems of Shahnameh.>,
#  <Sentence: In present-day Iran, cafés are trendy mostly in urban areas, where a variety of brews and desserts are served.>,
#  <Sentence: Turkish coffee is also popular in Iran, more specifically among Iranian Azeris.>,
#  <Sentence: Wine (mey) has also a significant presence in Iranian culture.>,
#  <Sentence: Shirazi wine is Iran's historically most famous wine production, originating from the city of Shiraz.>,
#  <Sentence: By the 9th century, the city of Shiraz had already established a reputation for producing the finest wine in the world,  and was Iran's wine capital.>,
#  <Sentence: Since the 1979 Revolution, alcoholic beverages have been prohibited in Iran; though non-Muslim recognized minorities (i.e. Christians, Jews, and Zoroastrians) are allowed to produce alcoholic beverages for their own use.>,
#  <Sentence: While non-alcoholic beer (ābjow) is available from legal outlets, other citizens prepare their alcoholic beverages illegally through the minority     and largely from Iraqi Kurdistan and Turkey.>,
#  <Sentence: Araq sagi, literally meaning "doggy distillate", is a type of distilled alcoholic beverage in Iran which contains at least 65% pure ethanol.>,
#  <Sentence: It is usually produced at homes from raisins, and is similar to Turkish rakı.>,
#  <Sentence: Prior to the 1979 Revolution, it had been produced traditionally in several cities of Iran.>,
#  <Sentence: Since it was outlawed following the 1979 Revolution, it has become a black market and underground business.The following table lists several Iranian cold beverages.The Azerbaijani people, living primarily in the region of Azerbaijan in northwestern Iran, have a number of local dishes that include Bonab kabab (Binab kababı),  the dumpling dish of joshpara (düşbərə), an offal-based dish named jaqul baqul typically containing liver and heart,  a variety of āsh called kələcoş,  a variation of qeyme that is called pıçaq, and a variation of kufte that is called Tabriz meatballs.>,
#  <Sentence: There is also the traditional pastry of shekerbura (şəkərbura), which is identical to Khorasan's shekarpare (šekarpāre).>,
#  <Sentence: Despite the influences from Turkey, the food tastes noticeably Iranian, though also with its own unique features, such as using more lemon juice and butter than other groups of Iranians.>,
#  <Sentence: Meat and dates are the main ingredients in the cuisine of Iran's southeastern region of Baluchistan.>,
#  <Sentence: Rice is primarily cultivated in the region of Makran.>,
#  <Sentence: Foods that are specific to the Iranian region of Baluchistan include tanurche (tarōnča; tanurče), a local variety of grilled meat that is prepared in a tanur, doogh-pa (dōq-pâ), a type of khoresh that contains doogh, and tabahag (tabâhag), that is meat prepared with pomegranate powder.>,
#  <Sentence: Baluchi cuisine also includes several date-based dishes, as well as various types of bread.>,
#  <Sentence: The southern coast of the Caspian Sea, which consists of the Iranian provinces of Gilan, Mazanderan, Alborz, and Golestan, has a fertile environment that is also reflected in its cuisine.>,
#  <Sentence: Kateh is a method of cooking rice that originates from this region.>,
#  <Sentence: This type of rice dish is also eaten there as a breakfast meal, either heated with milk and jam or cold with cheese and garlic.>,
#  <Sentence: Caviar fish roes also hail from this region, and are typically served with eggs in frittatas and omelettesor eaten simply with Lavash and Butter.>,
#  <Sentence: Fish is commonly eaten in the Gilan province, where Caspian Kutum is a   and usually served   along with rice.>,
#  <Sentence: Smoked fish (Persian: ماهی دودی, Romanized: Mahi doodi) is also popular in   and usually incorporated into rice by steaming the two together.>,
#  <Sentence: Local cookies (koluče) of the region are popular desert items,  particularly those from the region of Fuman.>,
#  <Sentence: Another notable dessert from this region is Reshteh Khoshkar (Persian: رشته خشکار), consisting of fried rice flour dough filled with sugar and nuts.>,
#  <Sentence: Medlar is also commonly eaten in   and locally referred to as "Konos" (Persian: کونوس).The region of Kurdistan in western Iran is home to a variety of local āsh, pilaf, and stew dishes.>,
#  <Sentence: Some local Kurdish dishes include a traditional grilled rib meat that is called dande kabāb,  a type of khoresh made of chives that is called xoreš-e tare,  and a dish of rice and potatoes that is called sib polow.>,
#  <Sentence: The food of southern Iran is typically spicy.>,
#  <Sentence: Mahyawa is a tangy sauce made of fermented fish in this region.>,
#  <Sentence: [citation   Being a coastal region, Khuzestan's cuisine includes especially seafood, as well as some unique local beverages.>,
#  <Sentence: In southern Khuzestan, there is also a variation of kufte that is known as kibbeh and is made of ground meat, cracked wheat, different types of herbs and vegetables and various spices.Iran's Turkmen people are predominantly centered in the Iranian provinces of Golestan and North Khorasan.>,
#  <Sentence: Chegderme (čekderme) is a Turkmen dish made of rice, meat, and tomato paste.>,
#  <Sentence: The basic traditional Iranian breakfast consists of a variety of flat breads, butter cubes, white cheese, whipped heavy cream (sarshir; often sweetened with honey), nuts (especially walnuts) and a variety of fruit jams and spreads.Many cities and towns across Iran feature their own distinct versions of breakfast dishes.>,
#  <Sentence: Pache, a popular traditional dish widely eaten in Iran and the neighboring Caucasus, is almost always only served from three in the morning until sometime after dawn, and specialty restaurants (serving only pache) are only open during those hours.Traditional Iranian cooking is done in stages, at times needing hours of preparation and attention.>,
#  <Sentence: The outcome is a well-balanced mixture of herbs, meat, beans, dairy products, and vegetables.>,
#  <Sentence: Major staples of Iranian food that are usually eaten with every meal include rice, various herbs, cheese, a variety of flat breads, and some type of meat (usually poultry, beef, lamb, or fish).>,
#  <Sentence: Stew over rice is by far the most popular dish, and the constitution of these vary by region.Traditional Iranian table setting firstly involves the tablecloth, called sofre, and is spread out over either a table or a rug.>,
#  <Sentence: Main dishes are concentrated in the middle, surrounded by smaller dishes containing appetizers, condiments, and side dishes, all of which are nearest to the diners.>,
#  <Sentence: When the food is perfectly served, an invitation is made to seat at the sofre and start having the meal.>)

# %% [markdown]
# ### <font color="#48dbfb">  TextRankSummarizer

# %%
# Importer le TextRankSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer

def summarizer_textrank(text, num_sentences=5):
# Initialiser le modèle
    summarizer_textrank = TextRankSummarizer()

    # Summariser en 5 phrases
    summary = summarizer_textrank(parser.document, 5)

    # Regrouper les phrases
    text_summary = ""
    for sentence in summary:
        text_summary += str(sentence)

    # Afficher le summary
    return text_summary

# %% [markdown]
# ### <font color="#48dbfb">  LexRankSummarizer

# %%
# Importer LexRankSummarizer
from sumy.summarizers.lex_rank import LexRankSummarizer

def summarizer_lexrank(text, num_sentences=5):
# Initialiser le modèle
    summarizer_lexrank = LexRankSummarizer()

    # Summariser en 5 phrases
    summary = summarizer_lexrank(parser.document, 5)

    # Regrouper les phrases
    text_summary = ""
    for sentence in summary:
        text_summary += str(sentence)
        
    # Afficher le summary
    return text_summary

# %% [markdown]
# ### <font color="#48dbfb"> LsaSummarizer

# %%
# Importer LsaSummarizer
from sumy.summarizers.lsa import LsaSummarizer

def summarizer_lsa(text, num_sentences=5):
# Initialiser le modèle
    summarizer_lsa = LsaSummarizer()

    # Summariser en 5 phrases
    summary = summarizer_lsa(parser.document, 5)

    # Regrouper les phrases
    text_summary = ""
    for sentence in summary:
        text_summary += str(sentence)

    # Afficher le summary
    return text_summary

# %% [markdown]
# ### <font color="#48dbfb"> Deploiement sur Streamlite

# %%
def set_background(image_file):
    with open(image_file, "Slide01") as f:
        img_data = f.read()

    b64_encoded = base64.b64encode(img_data).decode()
    style = f"""
        <style>
        .stApp {{
            background-image: url(data:image/jpg;base64,{b64_encoded});
            background-size: cover;
        }}
        </style>
    """
    st.markdown(style, unsafe_allow_html=True)


st.title("Application de Summarization")

# Ajoutez des composants Streamlit pour interagir avec l'utilisateur
texte_utilisateur = st.text_area("Entrez le texte à résumer", "")

if st.button("Résumer Modèle TextSummarizer"):
    resultat = summarizer_textrank(texte_utilisateur)
    st.write("Résumé (TextSummarizer):", resultat)

if st.button("Résumer Modèle TextRankSummarizer"):
    resultat = summarizer_textrank(texte_utilisateur)
    st.write("Résumé (TextRankSummarizer):", resultat)

if st.button("Résumer Modèle LexRankSummarizer"):
    resultat = summarizer_lexrank(texte_utilisateur)
    st.write("Résumé (LexRankSummarizer):", resultat)

if st.button("Résumer Modèle LsaSummarizer"):
    resultat = summarizer_lsa(texte_utilisateur)
    st.write("Résumé (LsaSummarizer):", resultat)
